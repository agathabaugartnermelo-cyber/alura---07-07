# %% [markdown]
# <a href="https://colab.research.google.com/github/agathabaugartnermelo-cyber/alura---07-07/blob/main/aula15_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = "123456"
senha_criptografada = ""

for numero in senha:
    numero = int(numero) + 1
    senha_criptografada = senha_criptografada + str(numero)
    print(senha_criptografada)
# Out:
# 2
# 23
# 234
# 2345
# 23456
# 234567
